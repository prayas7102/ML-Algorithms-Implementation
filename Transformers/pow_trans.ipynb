# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from scipy import stats
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
excel_file_path = "./Concrete.csv"
df = pd.read_csv(
    excel_file_path, encoding="latin-1"
)
df.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
# 3   332.5  142.5     0.0  228.0               0.0            932.0
# 4   198.6  132.4     0.0  192.0               0.0            978.4
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27
# 3          594.0  365  41.05
# 4          825.5  360  44.30

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (1030, 9)
# cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64

# %%
X = df.drop(columns='csMPa')
Y = df.iloc[:,-1]
X_train, X_test,Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

def get_accuracy(X_train,Y_train,X_test,Y_test):
    Lr = LinearRegression()
    Lr.fit(X_train,Y_train)
    print(np.mean(cross_val_score(Lr,X_test,Y_test,scoring='r2')))

get_accuracy(X_train,Y_train,X_test,Y_test)
# Out:
# 0.6463791414778453

# %%
def draw_graph(X_train_inp):
    for col in X_train_inp.columns:
        plt.figure(figsize=(14,4))
        plt.subplot(121)
        sns.histplot(X_train_inp[col],kde=True)
        plt.title(col)
        plt.subplot(122)
        stats.probplot(X_train_inp[col],dist='norm',plot=plt)
        plt.title(col)
        plt.show()

# before transformation
draw_graph(X_train)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method = 'yeo-johnson') # yeo-johnson, box-cox
X_train_trans = pt.fit_transform(X_train+0.001)
X_test_trans = pt.transform(X_test+0.001)
pd.DataFrame({'cols':X_train.columns,'box-cox lamdas':pt.lambdas_})
# Out:
#                cols  box-cox lamdas
# 0            cement        0.174345
# 1              slag        0.015695
# 2            flyash       -0.161484
# 3             water        0.771305
# 4  superplasticizer        0.253896
# 5   coarseaggregate        1.130050
# 6     fineaggregate        1.783101
# 7               age        0.019841

# %%
# after transformation
get_accuracy(X_train_trans,Y_train,X_test_trans,Y_test)
# Out:
# 0.8112025978517323

# %%
X_train_trans = pd.DataFrame(X_train_trans, columns=X_train.columns)
draw_graph(X_train_trans)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
